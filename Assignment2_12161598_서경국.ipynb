# %% [markdown]
# <a href="https://colab.research.google.com/github/tjrudrnr2/A.I/blob/main/Assignment2_12161598_%EC%84%9C%EA%B2%BD%EA%B5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
# %matplotlib inline


# result is 0~9
num_classes = 10
input_shape = (28, 28, 1)

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# make model
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(16, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(16, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)
model.summary()

# train model
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", 
              optimizer="adam", 
              metrics=["accuracy"])

history = model.fit(x_train, y_train, 
                    batch_size=batch_size, 
                    epochs=epochs, 
                    validation_split=0.1)

train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']

score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_2 (Conv2D)           (None, 26, 26, 16)        160
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 16)        2320
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 16)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 400)               0
#
#  dropout_1 (Dropout)         (None, 400)               0
#
#  dense_1 (Dense)             (None, 10)                4010
#
# ...
# Total params: 6,490
# Trainable params: 6,490
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 422/422 [==============================] - 21s 48ms/step - loss: 0.6519 - accuracy: 0.7900 - val_loss: 0.1433 - val_accuracy: 0.9632
# Epoch 2/15
# ...

# %% [markdown]
# # Part 2-1
# ## Increase layer

# %%
# result is 0~9
num_classes = 10
input_shape = (28, 28, 1)

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# make model
# add layers
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(16, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(16, kernel_size=(3, 3), padding="same", activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(16, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(16, kernel_size=(3, 3), padding="same", activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)
model.summary()

# train model
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", 
              optimizer="adam", 
              metrics=["accuracy"])

history = model.fit(x_train, y_train, 
                    batch_size=batch_size, 
                    epochs=epochs, 
                    validation_split=0.1)

#evaluate
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 26, 26, 16)        160
#
#  max_pooling2d_4 (MaxPooling  (None, 13, 13, 16)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 13, 13, 16)        2320
#
#  max_pooling2d_5 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 16)          2320
#
#  max_pooling2d_6 (MaxPooling  (None, 2, 2, 16)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 2, 2, 16)          2320
#
#  max_pooling2d_7 (MaxPooling  (None, 1, 1, 16)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 16)                0
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_2 (Dense)             (None, 10)                170
#
# ...
# Total params: 7,290
# Trainable params: 7,290
# Non-trainable params: 0
# ...

# %% [markdown]
# # Part 2-2
# ## Decrease filter

# %%
# result is 0~9
num_classes = 10
input_shape = (28, 28, 1)

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# make model
# add layers
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(16, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(16, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)
model.summary()

# train model
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", 
              optimizer="adam", 
              metrics=["accuracy"])

history = model.fit(x_train, y_train, 
                    batch_size=batch_size, 
                    epochs=epochs, 
                    validation_split=0.1)

#evaluate
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_8 (Conv2D)           (None, 26, 26, 16)        160
#
#  max_pooling2d_8 (MaxPooling  (None, 13, 13, 16)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 11, 11, 16)        2320
#
#  max_pooling2d_9 (MaxPooling  (None, 5, 5, 16)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 400)               0
#
#  dropout_3 (Dropout)         (None, 400)               0
#
#  dense_3 (Dense)             (None, 10)                4010
#
# ...
# Total params: 6,490
# Trainable params: 6,490
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.6599 - accuracy: 0.7887 - val_loss: 0.1362 - val_accuracy: 0.9643
# Epoch 2/15
# ...

# %% [markdown]
# # Part 2-3
# ## Decrease batch and Increase epoch

# %%
# result is 0~9
num_classes = 10
input_shape = (28, 28, 1)

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# make model
# add layers
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(16, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(16, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)
model.summary()

# train model
batch_size = 64
epochs = 25

model.compile(loss="categorical_crossentropy", 
              optimizer="adam", 
              metrics=["accuracy"])

history = model.fit(x_train, y_train, 
                    batch_size=batch_size, 
                    epochs=epochs, 
                    validation_split=0.1)

#evaluate
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_10 (Conv2D)          (None, 26, 26, 16)        160
#
#  max_pooling2d_10 (MaxPoolin  (None, 13, 13, 16)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 11, 11, 16)        2320
#
#  max_pooling2d_11 (MaxPoolin  (None, 5, 5, 16)         0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 400)               0
#
#  dropout_4 (Dropout)         (None, 400)               0
#
#  dense_4 (Dense)             (None, 10)                4010
#
# ...
# Total params: 6,490
# Trainable params: 6,490
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 844/844 [==============================] - 25s 29ms/step - loss: 0.4985 - accuracy: 0.8423 - val_loss: 0.1094 - val_accuracy: 0.9713
# Epoch 2/25
# ...

# %% [markdown]
# ## Part 1 결과
# Test loss: 0.043140385299921036
# Test accuracy: 0.98580002784729
#
# 기존 실습 코드에서 filter의 수를 16개로 통일하여 실행시켰다.
#
# ## Part 2-1 결과 ( layer 추가 )
# Test loss: 0.061904747039079666
# Test accuracy: 0.9824000000953674
#
# layer를 추가하였을 때 accuracy가 증가시켰더니 accuracy는 증가하였지만 loss도 증가하였다. 이는 maxpooling이 지나치게 많아 과적합이 일어난 것으로 보인다. 이 때, 사이즈 문제로 padding을 활용하였다.
#
# ## Part 2-2 결과 ( filter 감소 )
# Test loss: 0.0362127348780632
# Test accuracy: 0.9876999855041504
#
# Conv layer에서 filter의 개수를 증가시켰더니 loss 감소 및 accuracy가 증가하였다. 이를 통해 filter의 개수가 모델의 성능에 영향을 미친다는 것을 알 수 있다.
#
# ## Part 2-3 결과 ( batch 감소, epoch 증가 )
# Test loss: 0.03387134149670601
# Test accuracy: 0.9887999892234802
#
# batch를 감소시키고 epoch를 증가하여 훈련 과정을 늘려보았다. 2-2의 경우와 마찬가지로 loss 감소 및 accuracy가 증가한 것을 확인할 수 있다.
#
# 위의 결과들을 종합해봤을 때 layer의 깊이, filter의 개수, batch 그리고 epoch 모두 모델의 성능에 관여함을 알 수 있다.
