# %% [markdown]
# <a href="https://colab.research.google.com/github/tjrudrnr2/Pytorch/blob/main/Sigmoid%20Functino.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
  return 1/(1+np.exp(-x))

x = np.arange(-5.0, 5.0, 0.1)
y=  sigmoid(x)

# # W가 1이고 b가 0인 그래프
# plt.plot(x, y, 'g')
# plt.plot([0,0],[1.0,0.0], ':') # 가운데 점선 추가
# plt.title('Sigmoid Function')
# plt.show()

# W값 변화
x = np.arange(-5.0, 5.0, 0.1)
y1 = sigmoid(0.5*x)
y2 = sigmoid(x)
y3 = sigmoid(2*x)

plt.plot(x,y1,'r',linestyle='--') # W의 값이 0.5
plt.plot(x,y2,'g')                # W의 값이 1
plt.plot(x,y3,'b',linestyle='--') # W의 값이 2
plt.plot([0,0],[1.0,0.0], ':')
plt.title('Sigmoid Function')
plt.show()
